# %% [markdown]
# <a href="https://colab.research.google.com/github/murodjon2423/BOOSTX2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = [
    [2.5, 21], [5.1, 47], [3.2, 27], [8.5, 75], [3.5, 30], [1.5, 20], [9.2, 88],
    [5.5, 60], [8.3, 81], [2.7, 25], [7.7, 85], [5.9, 62], [4.5, 41], [3.3, 42],
    [1.1, 17], [8.9, 95], [2.5, 30], [1.9, 24], [6.1, 67], [7.4, 69], [2.7, 30],
    [4.8, 54], [3.8, 35], [6.9, 76], [7.8, 86], [4.2, 49], [9.5, 90], [5.8, 63],
    [2.3, 23], [4.7, 50], [1.6, 19], [9, 92], [6.2, 68], [8.1, 82], [3.9, 38],
    [2.2, 22], [7.1, 73], [6.3, 66], [5.3, 56], [4.4, 45], [1.8, 21], [9.4, 93],
    [6.7, 71], [3.7, 37], [7.3, 77], [4.1, 44], [8, 79], [3.1, 28], [1.3, 16],
    [5.7, 59], [2.8, 29], [7.9, 80], [6.6, 72], [3.6, 36], [2.4, 26], [4.6, 48],
    [8.4, 84], [1.7, 18], [5.2, 53], [6.4, 64], [7.6, 78], [9.3, 94], [3.4, 33],
    [2.1, 20], [5.4, 55], [8.2, 83], [1.4, 15], [9.6, 98], [6.8, 74], [7.5, 70],
    [4.3, 43], [6.5, 65], [8.7, 87], [3, 27], [2.9, 31], [1.2, 14], [9.7, 96],
    [4.9, 51], [5.6, 57], [8.6, 89], [2.6, 32], [7.2, 72], [1, 12], [6, 61],
    [4, 40], [5, 52], [6.8, 67], [2, 18], [3, 34], [7, 73], [9.8, 99], [5.8, 60],
    [4.4, 44], [6.1, 63], [3.7, 37], [8, 84]
]

df = pd.DataFrame(data, columns=["Hours", "Scores"])

print(df)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# ..    ...     ...
# 91    5.8      60
# 92    4.4      44
# 93    6.1      63
# 94    3.7      37
# 95    8.0      84
#
# [96 rows x 2 columns]

# %%
X = df['Hours']
Y = df['Scores']

# %%
import matplotlib.pyplot as plt
plt.plot(X, Y, 'o')
plt.xlabel('Time Study')
plt.ylabel('Scores')
plt.title('Hours vs Scores')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()

model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

print(f"Test data uchun prognoz qilingan natijalar: {Y_pred}")
print(f"Haqiqiy natijalar: {Y_test.to_numpy()}")

print(f"Modelning aniqligi (R^2): {model.score(X_test, Y_test)}")
print(f"features target { X_train,Y_train}")
plt.scatter(X, Y, color="blue")
plt.plot(X, model.predict(X), color="red")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Linear Regression: Hours vs Scores")
plt.show()
# Out:
# Test data uchun prognoz qilingan natijalar: [28.01321679 50.63517747 31.94747083 38.83241538 82.10920972 87.02702726
#  76.20782868 68.33932061 27.02965329 78.17495569 55.55299501 18.17758172
#  62.43793957 36.86528836 90.96128129 95.87909883 46.70092344 39.81597889
#  37.84885187 51.61874098]
# Haqiqiy natijalar: [32 51 27 37 82 89 70 71 21 85 55 19 67 30 92 90 41 35 36 52]
# Modelning aniqligi (R^2): 0.9708871356050831
# features target (    Hours
# 40    1.8
# 67    9.6
# 15    8.9
# 68    6.8
# 88    3.0
# ..    ...
# 60    7.6
# 71    6.5
# 14    1.1
# 92    4.4
# 51    7.9
#
# [76 rows x 1 columns], 40    21
# 67    98
# 15    95
# 68    74
# 88    34
#       ..
# 60    78
# 71    65
# 14    17
# 92    44
# 51    80
# Name: Scores, Length: 76, dtype: int64)

# %%
model = LinearRegression()
model.fit(X, Y)

# Ko'rsatkichlar
b_0 = model.intercept_  # Intercept
b_1 = model.coef_[0]    # Slope (koeffitsient)

print(f"Intercept (b0): {b_0}")
print(f"Slope (b1): {b_1}")
# Out:
# Intercept (b0): 1.8635766281174497
# Slope (b1): 9.901318259246043

# %%
score = model.score(X.values,Y)
print('cof', score)
# Out:
# cof 0.9813673346564977
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

new_data = np.array([[3], [5]])
result = model.predict(new_data)


print(f"Prediction for new data (3 and 5 hours): {result}")
# Out:
# Prediction for new data (3 and 5 hours): [31.56753141 51.37016792]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
